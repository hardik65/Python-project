# %%
import pandas as pd
import numpy as np
import pylab as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("airline_passenger_satisfaction.csv")

# %%
 # Shuffle and drop data 
df = data.sample(n=1000, random_state =1)

# %%
data.head()
# Out:
#    Unnamed: 0  Gender      customer_type  age   type_of_travel customer_class  \
# 0           0    Male     Loyal Customer   13  Personal Travel       Eco Plus
# 1           1    Male  disloyal Customer   25  Business travel       Business
# 2           2  Female     Loyal Customer   26  Business travel       Business
# 3           3  Female     Loyal Customer   25  Business travel       Business
# 4           4    Male     Loyal Customer   61  Business travel       Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         129880 non-null  int64
#  1   Gender                             129880 non-null  object
#  2   customer_type                      129880 non-null  object
#  3   age                                129880 non-null  int64
#  4   type_of_travel                     129880 non-null  object
#  5   customer_class                     129880 non-null  object
#  6   flight_distance                    129880 non-null  int64
#  7   inflight_wifi_service              129880 non-null  int64
#  8   departure_arrival_time_convenient  129880 non-null  int64
#  9   ease_of_online_booking             129880 non-null  int64
#  10  gate_location                      129880 non-null  int64
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0            age  flight_distance  inflight_wifi_service  \
# count  129880.000000  129880.000000    129880.000000          129880.000000
# mean    64939.500000      39.427957      1190.316392               2.728696
# std     37493.270818      15.119360       997.452477               1.329340
# min         0.000000       7.000000        31.000000               0.000000
# 25%     32469.750000      27.000000       414.000000               2.000000
# 50%     64939.500000      40.000000       844.000000               3.000000
# 75%     97409.250000      51.000000      1744.000000               4.000000
# max    129879.000000      85.000000      4983.000000               5.000000
#
#        departure_arrival_time_convenient  ease_of_online_booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# ...

# %%
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data.columns
# Out:
# Index(['Gender', 'customer_type', 'age', 'type_of_travel', 'customer_class',
#        'flight_distance', 'inflight_wifi_service',
#        'departure_arrival_time_convenient', 'ease_of_online_booking',
#        'gate_location', 'food_and_drink', 'online_boarding', 'seat_comfort',
#        'inflight_entertainment', 'onboard_service', 'leg_room_service',
#        'baggage_handling', 'checkin_service', 'inflight_service',
#        'cleanliness', 'departure_delay_in_minutes', 'arrival_delay_in_minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Gender, customer_type, age, type_of_travel, customer_class, flight_distance, inflight_wifi_service, departure_arrival_time_convenient, ease_of_online_booking, gate_location, food_and_drink, online_boarding, seat_comfort, inflight_entertainment, onboard_service, leg_room_service, baggage_handling, checkin_service, inflight_service, cleanliness, departure_delay_in_minutes, arrival_delay_in_minutes, satisfaction]
# Index: []
#
# [0 rows x 23 columns]

# %%
fizsize_with_subplots = (10, 10)
# Set up a grid of plots for categorical data and numerical data
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (3, 2)

# Plot Gender counts
plt.subplot2grid(fig_dims, (0, 0))
data['Gender'].value_counts().plot(kind='bar', title='Gender Counts')
plt.xticks(rotation=0)

# Plot Customer Type counts
plt.subplot2grid(fig_dims, (0, 1))
data['customer_type'].value_counts().plot(kind='bar',title='Customer Type Counts')
plt.xticks(rotation=0)

# Plot Type of Travel counts
plt.subplot2grid(fig_dims, (1, 0))
data['type_of_travel'].value_counts().plot(kind='bar', 
                                    title='Type of Travel Counts')
plt.xticks(rotation=0)

# Plot Class counts
plt.subplot2grid(fig_dims, (1, 1))
data['customer_class'].value_counts().plot(kind='bar', 
                                         title='Class Counts')
plt.xticks(rotation=0)

# Plot Satisfaction counts
plt.subplot2grid(fig_dims, (2, 0))
data['satisfaction'].value_counts().plot(kind='bar', 
                                         title='Satisfaction Counts')
plt.xticks(rotation=0)

# Plot Satisfaction counts
plt.subplot2grid(fig_dims, (2, 1))
data['departure_arrival_time_convenient'].value_counts().plot(kind='bar', 
                                         title='Departure/Arrival time convenient Counts')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '4'),
#   Text(1, 0, '5'),
#   Text(2, 0, '3'),
#   Text(3, 0, '2'),
#   Text(4, 0, '1'),
#   Text(5, 0, '0')])

# %%
plt.subplots(figsize=(12,5))
correlation = data.corr()
sns.heatmap(correlation,annot=True,cmap='BuPu')
plt.title('Correlation between variables')
plt.xticks(rotation=90)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5]),
#  [Text(0.5, 0, 'age'),
#   Text(1.5, 0, 'flight_distance'),
#   Text(2.5, 0, 'inflight_wifi_service'),
#   Text(3.5, 0, 'departure_arrival_time_convenient'),
#   Text(4.5, 0, 'ease_of_online_booking'),
#   Text(5.5, 0, 'gate_location'),
#   Text(6.5, 0, 'food_and_drink'),
#   Text(7.5, 0, 'online_boarding'),
#   Text(8.5, 0, 'seat_comfort'),
#   Text(9.5, 0, 'inflight_entertainment'),
#   Text(10.5, 0, 'onboard_service'),
#   Text(11.5, 0, 'leg_room_service'),
#   Text(12.5, 0, 'baggage_handling'),
#   Text(13.5, 0, 'checkin_service'),
#   Text(14.5, 0, 'inflight_service'),
#   Text(15.5, 0, 'cleanliness'),
#   Text(16.5, 0, 'departure_delay_in_minutes'),
#   Text(17.5, 0, 'arrival_delay_in_minutes')])

# %% [markdown]
# # Transformations

# %%
# View value counts for each column
for x in data.columns:
    print(data[x].value_counts())
# Out:
# Female    65899
# Male      63981
# Name: Gender, dtype: int64
# Loyal Customer       106100
# disloyal Customer     23780
# Name: customer_type, dtype: int64
# 39    3692
# 25    3511
# 40    3209
# 44    3104
# 41    3089
#       ...
# 74      61
# 76      60
# 79      52
# 78      44
# 85      25
# Name: age, Length: 75, dtype: int64
# Business travel    89693
# Personal Travel    40187
# Name: type_of_travel, dtype: int64
# Business    62160
# Eco         58309
# Eco Plus     9411
# Name: customer_class, dtype: int64
# 337     841
# 594     505
# 404     480
# 862     473
# 2475    470
#        ...
# 1484      1
# 778       1
# 1434      1
# 1361      1
# 884       1
# Name: flight_distance, Length: 3821, dtype: int64
# 2    32320
# 3    32185
# 4    24775
# 1    22328
# 5    14356
# 0     3916
# Name: inflight_wifi_service, dtype: int64
# 4    31880
# 5    27998
# 3    22378
# 2    21534
# 1    19409
# 0     6681
# Name: departure_arrival_time_convenient, dtype: int64
# ...

# %%
data['Gender'].value_counts()
# Out:
# Female    65899
# Male      63981
# Name: Gender, dtype: int64

# %%
data['Gender'] = data['Gender'].map({'Female':1, 'Male': 0}).astype(int)
data['Gender'].value_counts()
# Out:
# 1    65899
# 0    63981
# Name: Gender, dtype: int64

# %%
data['customer_type'].value_counts()
# Out:
# Loyal Customer       106100
# disloyal Customer     23780
# Name: customer_type, dtype: int64

# %%
data['customer_type'] = data['customer_type'].map({'Loyal Customer':1, 'disloyal Customer': 0}).astype(int)
data['customer_type'].value_counts()
# Out:
# 1    106100
# 0     23780
# Name: customer_type, dtype: int64

# %%
data['type_of_travel'].value_counts()
# Out:
# Business travel    89693
# Personal Travel    40187
# Name: type_of_travel, dtype: int64

# %%
data['type_of_travel'] = data['type_of_travel'].map({'Business travel':1, 'Personal Travel': 0}).astype(int)
data['type_of_travel'].value_counts()
# Out:
# 1    89693
# 0    40187
# Name: type_of_travel, dtype: int64

# %%
data['customer_class'].value_counts()
# Out:
# Business    62160
# Eco         58309
# Eco Plus     9411
# Name: customer_class, dtype: int64

# %%
data['customer_class'] = data['customer_class'].map({'Business':2, 'Eco Plus': 1, 'Eco' :0}).astype(int)
data['customer_class'].value_counts()
# Out:
# 2    62160
# 0    58309
# 1     9411
# Name: customer_class, dtype: int64

# %%
data['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    73452
# satisfied                  56428
# Name: satisfaction, dtype: int64

# %%
data['satisfaction'] = data['satisfaction'].map({'neutral or dissatisfied':0, 'satisfied': 1}).astype(int)
data['satisfaction'].value_counts()
# Out:
# 0    73452
# 1    56428
# Name: satisfaction, dtype: int64

# %%
data.describe()
# Out:
#               Gender  customer_type            age  type_of_travel  \
# count  129880.000000  129880.000000  129880.000000   129880.000000
# mean        0.507384       0.816908      39.427957        0.690584
# std         0.499947       0.386743      15.119360        0.462255
# min         0.000000       0.000000       7.000000        0.000000
# 25%         0.000000       1.000000      27.000000        0.000000
# 50%         1.000000       1.000000      40.000000        1.000000
# 75%         1.000000       1.000000      51.000000        1.000000
# max         1.000000       1.000000      85.000000        1.000000
#
#        customer_class  flight_distance  inflight_wifi_service  \
# count   129880.000000    129880.000000          129880.000000
# mean         1.029650      1190.316392               2.728696
# std          0.962636       997.452477               1.329340
# min          0.000000        31.000000               0.000000
# ...

# %%
data.isnull().sum()
# Out:
# Gender                                 0
# customer_type                          0
# age                                    0
# type_of_travel                         0
# customer_class                         0
# flight_distance                        0
# inflight_wifi_service                  0
# departure_arrival_time_convenient      0
# ease_of_online_booking                 0
# gate_location                          0
# food_and_drink                         0
# online_boarding                        0
# seat_comfort                           0
# inflight_entertainment                 0
# onboard_service                        0
# leg_room_service                       0
# baggage_handling                       0
# checkin_service                        0
# inflight_service                       0
# cleanliness                            0
# departure_delay_in_minutes             0
# arrival_delay_in_minutes             393
# satisfaction                           0
# ...

# %%
data['arrival_delay_in_minutes'].fillna(data['departure_delay_in_minutes'], inplace = True)

# %%
data.isnull().sum()
# Out:
# Gender                               0
# customer_type                        0
# age                                  0
# type_of_travel                       0
# customer_class                       0
# flight_distance                      0
# inflight_wifi_service                0
# departure_arrival_time_convenient    0
# ease_of_online_booking               0
# gate_location                        0
# food_and_drink                       0
# online_boarding                      0
# seat_comfort                         0
# inflight_entertainment               0
# onboard_service                      0
# leg_room_service                     0
# baggage_handling                     0
# checkin_service                      0
# inflight_service                     0
# cleanliness                          0
# departure_delay_in_minutes           0
# arrival_delay_in_minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.model_selection import train_test_split

new_data = data.drop(['satisfaction'], axis=1)
x = new_data.values 
y = data['satisfaction'].values

# Normalize features
for feature in range (x.shape[1]):
    min = x[:,feature].min()
    max = x[:,feature].max()
    x[:,feature] = (x[:,feature]-min) / (max-min)
    
X_train, X_test, Y_train, Y_test = train_test_split (x, y, test_size=0.2, random_state=42)
print("The training data size is : {} ".format(X_train.shape))
print("The test data size is : {} ".format(X_test.shape))
# Out:
# The training data size is : (103904, 22)
# The test data size is : (25976, 22)

# %%
from sklearn.linear_model import LogisticRegression

logr = LogisticRegression()
logr.fit (X_train, Y_train)
logr_training_score = 100*logr.score(X_train,Y_train)
logr_test_score = 100*logr.score(X_test,Y_test)
print("Logistic Regression accuracy. Train : {:.2f}%, Test: {:.2f}%. ".format(logr_training_score, logr_test_score))
# Out:
# Logistic Regression accuracy. Train : 87.36%, Test: 87.56%.

# %%
Y_pred = logr.predict(X_test)

# Confusion Matrix: 
TP = np.sum((Y_test==1) & (Y_pred==1))
TN = np.sum((Y_test==0) & (Y_pred==0))
FP = np.sum((Y_test==0) & (Y_pred==1))
FN = np.sum((Y_test==1) & (Y_pred==0))
print(TP, TN, FP, FN)
# Out:
# 9523 13222 1400 1831

# %%
precision = TP/(TP+FP)
recall = TP/(TP+FN)
print(precision)
print(recall)
# Out:
# 0.8718300833104459
# 0.8387352474898714

# %%
from sklearn.metrics import classification_report



predictions = logr.predict(X_test)



print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     14622
#            1       0.87      0.84      0.85     11354
#
#     accuracy                           0.88     25976
#    macro avg       0.88      0.87      0.87     25976
# weighted avg       0.88      0.88      0.88     25976

# %%
df = data.sample(n=1000, random_state = 42)

# %%
from sklearn.model_selection import train_test_split

used_data = df.drop (['satisfaction'], axis=1)
x = used_data.values 
y = df['satisfaction'].values

# Normalize features
for feature in range (x.shape[1]):
    min = x[:,feature].min()
    max = x[:,feature].max()
    x[:,feature] = (x[:,feature]-min) / (max-min)
    
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size=0.2, random_state=42)
print("The training data size is : {} ".format(x_train.shape))
print("The test data size is : {} ".format(x_test.shape))
# Out:
# The training data size is : (800, 22)
# The test data size is : (200, 22)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# define function
base_knn = KNeighborsClassifier()

# define a list of parameters
param_knn = {'n_neighbors': range(1, 25)}  

#apply grid search
grid_knn = GridSearchCV(base_knn, param_knn, cv = 5)
grid_knn.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_neighbors': range(1, 25)}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring=None, verbose=0)

# %%
# the best hyperparameter chosen:
print(grid_knn.best_params_)

# When best case, the validation score of through CV is:
print(grid_knn.best_score_)

train_score_array = grid_knn.cv_results_['mean_test_score']
train_score_array
# Out:
# {'n_neighbors': 16}
# 0.88375
# array([0.8575 , 0.86375, 0.87   , 0.87625, 0.87375, 0.8775 , 0.87625,
#        0.8725 , 0.8775 , 0.87625, 0.8825 , 0.88   , 0.8825 , 0.8825 ,
#        0.87875, 0.88375, 0.8775 , 0.87875, 0.8775 , 0.87625, 0.875  ,
#        0.87375, 0.875  , 0.875  ])

# %%
grid_knn.fit(x_test, y_test) 
test_score_array = grid_knn.cv_results_['mean_test_score']
test_score_array
# Out:
# array([0.845, 0.84 , 0.885, 0.845, 0.865, 0.87 , 0.895, 0.875, 0.88 ,
#        0.88 , 0.875, 0.875, 0.87 , 0.875, 0.87 , 0.87 , 0.875, 0.87 ,
#        0.865, 0.865, 0.85 , 0.85 , 0.865, 0.845])

# %%
x_axis = range(1,25)
# %matplotlib inline



plt.subplots(figsize = (30,5))
plt.plot(x_axis, train_score_array, label = 'Train Score', c = 'g')
plt.plot(x_axis, test_score_array, label = 'Test Score', c='b')
plt.xlabel('n_neighbors')
plt.ylabel('Accuracy')
plt.xticks(x_axis, np.arange(24)+1)
plt.grid()
plt.legend()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# define function
base_knn = KNeighborsClassifier()

# define a list of parameters
param_knn = {'n_neighbors': [16]}  

#apply grid search
grid_knn = GridSearchCV(base_knn, param_knn, cv = 5)
grid_knn.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=None, param_grid={'n_neighbors': [16]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
knn_training_score = 100*grid_knn.score(X_train,Y_train)
knn_test_score = 100*grid_knn.score(X_test,Y_test)
print("KNN accuracy. Train : {:.2f}%, Test: {:.2f}%. ".format(knn_training_score, knn_test_score))
# Out:
# KNN accuracy. Train : 93.40%, Test: 92.76%.

# %%
from sklearn.metrics import classification_report



predictions = grid_knn.predict(X_test)



print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94     14622
#            1       0.96      0.87      0.91     11354
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.92      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %% [markdown]
# | Model | Parameters | Train Scores | Test Scores|
# | --- | --- | --- | --- |
# | **Logistic Regression** | NA | 87.36% | 87.56% |
# | **KNN Classifier** | 'n_neighbors': 16 | 93.40% | 92.76% |
# | **Decision Tree** | 'max_depth': 7, 'max_leaf_nodes': 19, 'min_samples_split': 2 | 91.89% | 92.26% |

# %%
# GridSearch + CV
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV



# Define Function
opt_tree = DecisionTreeClassifier(random_state = 0)




DT_params = {
'max_depth': range(3,18),
'min_samples_split': range(2,11),
'max_leaf_nodes': range(2,20)
}


grid_tree = GridSearchCV(opt_tree, DT_params, cv=5)



# Train the model, and report accuracy
grid_tree.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=0, splitter='best'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': range(3, 18),
# ...

# %%
# the best hyperparameter chosen:
print('Best Hyperparameter: ', grid_tree.best_params_)



# test accuracy
print('Test Accuracy: ', grid_tree.score(X_test, Y_test))



# When k=25 (best case), the validation score of through CV is:
print('Test Validation: ', grid_tree.best_score_)
# Out:
# Best Hyperparameter:  {'max_depth': 7, 'max_leaf_nodes': 19, 'min_samples_split': 2}
# Test Accuracy:  0.912419156144133
# Test Validation:  0.9148156203802623

# %%
# Plot the decision tree
from sklearn import tree
import matplotlib.pyplot as plt



fig = plt.figure(figsize=(45,10)) # set a proper figure size (in case that the figure is too small to read or ratio is not proper)
tree.plot_tree(grid_tree.best_estimator_.fit(X_train, Y_train),
feature_names = list(df.columns), # specify variable names
class_names = ['neutral or dissatisfied', 'satisfied'], # specify class (Y) names
filled = True, impurity = False, # whether to color the boxes, whether to report gini index
fontsize = 12) # set fontsize to read
plt.show()



# save the figure to read through the boxes, it is saved under the same directory as the coding doc.
fig.savefig("decision_tree.jpg")

# %%
from sklearn.metrics import classification_report



predictions = grid_tree.predict(X_test)



print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92     14622
#            1       0.91      0.88      0.90     11354
#
#     accuracy                           0.91     25976
#    macro avg       0.91      0.91      0.91     25976
# weighted avg       0.91      0.91      0.91     25976
